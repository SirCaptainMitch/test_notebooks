# %%
import sqlalchemy as sa
import pandas as pd

from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation, writers
import numpy as np

# %%
# Enable interactive plot
# %matplotlib inline

# %%
SERVER='192.168.0.245'
SQLSERVER_DATABASE='lookingglass'
SQLSERVER_USER='thecaptain'
SQLSERVER_PASSWORD='99Redbal00ns'
PORT=1433
SQLSERVER_BASE_URI = 'mssql+pyodbc://{USER}:{PWD}@{SERVER}:{PORT}/{DATABASE}?driver=ODBC+Driver+17+for+SQL+Server'

engine = sa.create_engine(SQLSERVER_BASE_URI.format(
  SERVER=SERVER,
  DATABASE=SQLSERVER_DATABASE,
  USER=SQLSERVER_USER,
  PWD=SQLSERVER_PASSWORD,
  PORT=PORT
))

# %%
test = pd.read_sql_table(table_name='ngs_match', con=engine)

# %%
test.head()
# Out:
#                ngs_match_id  game_number         game_winner  \
# 0  61f23d37459c7f001d0bc15b          1.0      beyonce gnolls
# 1  61f23d37459c7f001d0bc15b          2.0          icc queens
# 2  61f23d37459c7f001d0bc15b          3.0          icc queens
# 3  61f23d37459c7f001d0bc18e          1.0  30 seconds to mosh
# 4  61f23d37459c7f001d0bc18e          2.0  30 seconds to mosh
#
#                                                  url  \
# 0  ngs_2-5-2022_ICC_Queens_vs_Beyonce_Gnolls_Infe...
# 1  ngs_2-5-2022_ICC_Queens_vs_Beyonce_Gnolls_Batt...
# 2  ngs_2-5-2022_ICC_Queens_vs_Beyonce_Gnolls_Alte...
# 3  ngs_2-22-2022_30_Seconds_to_Mosh_vs_Beyonce_Gn...
# 4  ngs_2-22-2022_30_Seconds_to_Mosh_vs_Beyonce_Gn...
#
#                                           parsed_url match_type  forfeit  \
# 0  https://www.heroesprofile.com/NGS/Match/Single...   seasonal    False
# 1  https://www.heroesprofile.com/NGS/Match/Single...   seasonal    False
# 2  https://www.heroesprofile.com/NGS/Match/Single...   seasonal    False
# 3  https://www.heroesprofile.com/NGS/Match/Single...   seasonal    False
# 4  https://www.heroesprofile.com/NGS/Match/Single...   seasonal    False
#
#    season  match_round division_concat  ... scheduled_start_time  \
# 0      13            1          e-east  ...  2022-02-04 20:00:00
# 1      13            1          e-east  ...  2022-02-04 20:00:00
# 2      13            1          e-east  ...  2022-02-04 20:00:00
# 3      13            4          e-east  ...  2022-02-21 20:00:00
# 4      13            4          e-east  ...  2022-02-21 20:00:00
#
#     scheduled_end_time                                        vod_links  \
# 0  2022-02-04 21:30:00                 ['https://youtu.be/bAXx8weKkKY']
# 1  2022-02-04 21:30:00                 ['https://youtu.be/bAXx8weKkKY']
# 2  2022-02-04 21:30:00                 ['https://youtu.be/bAXx8weKkKY']
# 3  2022-02-21 21:30:00  ['https://www.youtube.com/watch?v=cuMZq9WEboU']
# 4  2022-02-21 21:30:00  ['https://www.youtube.com/watch?v=cuMZq9WEboU']
#
#          match_id away_first_map_ban home_first_map_ban  \
# 0  rdzy6tkywlr3yn     Towers of Doom         Sky Temple
# 1  rdzy6tkywlr3yn     Towers of Doom         Sky Temple
# 2  rdzy6tkywlr3yn     Towers of Doom         Sky Temple
# 3  rdzy6tkywlr3z4     Braxis Holdout       Dragon Shire
# 4  rdzy6tkywlr3z4     Braxis Holdout       Dragon Shire
#
#         away_second_map_ban  home_second_map_ban  away_third_map_ban  \
# 0              Dragon Shire     Volskaya Foundry                None
# 1              Dragon Shire     Volskaya Foundry                None
# 2              Dragon Shire     Volskaya Foundry                None
# 3  Tomb of the Spider Queen         Alterac Pass                None
# 4  Tomb of the Spider Queen         Alterac Pass                None
#
#    home_third_map_ban
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
#
# [5 rows x 30 columns]

# %%
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
# Enable interactive plot
# %matplotlib notebook
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
anim = None

fig, ax = plt.subplots()

line, = ax.plot([])

ax.set_xlim(0, 2*np.pi)
ax.set_ylim(-1.1, 1.1)

def animate(frame_num):
    y = np.sin(x + 2*np.pi * frame_num/100)
    line.set_data((x, y))
    return line

anim = FuncAnimation(fig, animate, frames=100, interval=5)
plt.show()
# Out:
# c:\source\innovation\insight\lookingglass_playground\venv\lib\site-packages\matplotlib\animation.py:889: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you have outputted the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
# <div id='575d25f1-83a6-436c-ac2e-de7598ce41fd'></div>
